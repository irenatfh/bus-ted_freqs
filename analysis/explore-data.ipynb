# %%
import pandas as pd
import numpy as np

# %%
path_data = '../data/source/'

# %%
db_agency_line = pd.read_json(path_data + 'agency_line.json')
db_lines = pd.read_json(path_data + 'lines.json')
db_agencies = pd.read_json(path_data + 'agencies.json')

# %%
db_agency_line.head()
# Out:
#               agency_name                 line_name route_mode route_color  \
# 0  Bay Area Rapid Transit  Antioch to SFIA/Millbrae       rail      FFFF33
# 1  Bay Area Rapid Transit  Antioch to SFIA/Millbrae       rail      FFFF33
# 2  Bay Area Rapid Transit  Antioch to SFIA/Millbrae       rail      FFFF33
# 3  Bay Area Rapid Transit  Antioch to SFIA/Millbrae       rail      FFFF33
# 4  Bay Area Rapid Transit  Antioch to SFIA/Millbrae       rail      FFFF33
#
#                                            schedules
# 0  {'log_time': '2020-04-24T04:00:00.000Z', 'sche...
# 1  {'log_time': '2020-04-24T04:00:00.000Z', 'sche...
# 2  {'log_time': '2020-04-24T04:00:00.000Z', 'sche...
# 3  {'log_time': '2020-04-24T04:00:00.000Z', 'sche...
# 4  {'log_time': '2020-04-24T04:00:00.000Z', 'sche...

# %%
db_lines.head()
# Out:
#      region_name            region_tz  agency_id             agency_name  \
# 0  San Francisco  America/Los_Angeles         44  Bay Area Rapid Transit
# 1  San Francisco  America/Los_Angeles         44  Bay Area Rapid Transit
# 2  San Francisco  America/Los_Angeles         44  Bay Area Rapid Transit
# 3  San Francisco  America/Los_Angeles         44  Bay Area Rapid Transit
# 4  San Francisco  America/Los_Angeles         44  Bay Area Rapid Transit
#
#                                                lines
# 0  {'line_id': 490, 'line_name': 'Antioch to SFIA...
# 1  {'line_id': 491, 'line_name': 'Warm Springs/So...
# 2  {'line_id': 492, 'line_name': 'Millbrae/SFIA t...
# 3  {'line_id': 493, 'line_name': 'Warm Springs/So...
# 4  {'line_id': 494, 'line_name': 'Richmond to War...

# %%
db_agencies.iloc[25:30]
# Out:
#     id           name             timezone  \
# 25  sf  San Francisco  America/Los_Angeles
# 26  sf  San Francisco  America/Los_Angeles
# 27  sf  San Francisco  America/Los_Angeles
# 28  sf  San Francisco  America/Los_Angeles
# 29  sf  San Francisco  America/Los_Angeles
#
#                                           description  \
# 25  Data for San Francisco transportation. All of ...
# 26  Data for San Francisco transportation. All of ...
# 27  Data for San Francisco transportation. All of ...
# 28  Data for San Francisco transportation. All of ...
# 29  Data for San Francisco transportation. All of ...
#
#                                                 notes  \
# 25  Due to COVID-19, it's not yet clear how accura...
# 26  Due to COVID-19, it's not yet clear how accura...
# 27  Due to COVID-19, it's not yet clear how accura...
# 28  Due to COVID-19, it's not yet clear how accura...
# 29  Due to COVID-19, it's not yet clear how accura...
#
# ...
